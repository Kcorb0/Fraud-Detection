# %% [markdown]
# # Assignment 2: Fraud Detection

# %% [markdown]
# Author: Josh NM Blackmore <br>
# StID: 201776628

# %% [markdown]
# ## Case Study
#
# <p>An insurance company plans to utilise their historic insurance fraud dataset to predict the likelihood or the level of risk a customer poses. You can find the dataset above. Referring genuine claims cause customer stress and directly leads to customer loss, costing the company money (assume that any referred non-fraud case will lead to losing that customer). While obviously, fraud claims cost the company as well. Their main requirement is to use an unbiased predictive model capable of flagging and referring potential fraud cases for further investigation with a balanced error rate of 5%.</p>

# %% [markdown]
# ## 1 Aims, Objectives & Plan
# ### 1.1 Aims & Objectives
# This projects primary objective is to analyse a medium sized dataset containing insurance claims from an insurance company with the goal of identifying potential fraudulant claims. The project requires a minumum of two techniques to provide predictions or valuable insights.
#
# Provided datasets will be pre-processed with various techniques and the reasoning behind certain decisions.
#
# Secondly, a technical report which consists of a narration around the analysis conducted for the project. This will be a jupyter notebook document containing the key procedures taken for each step such as justifying choices made in pre-processing, the models solutions, various visualisations of the analysis and testing with performance metrics such as F1, recall, confusion matrix etc.
#
# ### 1.2 Plan
# - Gantt Chart

# %% [markdown]
# ## 2 Understanding the Case Study
# ### 2.1 Case Study Analysis
# In this section I will present my understanding of the case study with the 4 critical points found in the case description.
# #### 2.1.1 Predicting a Customers Level of Risk
# Each row of the datasets provide information for an individual customers claim with labels depicting if the claim was fraudulant or legitimate. The client needs to know what level of risk future clients pose for future cases, using historical data.
#
# #### 2.1.2 Cost of Fraudulant Cases for Customers and Company
# Cases provided contain various cost factors such as property claim, injury claims etc. Part of the case study specifies the need to highlight the cost risk for fraudulant cases company and customer alike, the case study specifies the risk of losing customers due to cost.
#
# #### 2.1.3 Unbiased Prediction Model to Flag Fraudulant Cases
# The case study specifies the need of unbiased predictions. This can be acheived in pre-processing ensuring the training/test data is well balanced with fair distributions. Techniques such as regularization and post-processing techniques such as equalizing false positives and false negatives.
#
# #### 2.1.4 Accuracy and Error Rate of the Models
# Accuracy measures are needed to ensure the model is making correct predictions/accurate insights, such as correctly classified instances. The error rate will also be calculated to complement accuracy. The case study specifies the client is expecting a balanced error rate of around 5%.

# %% [markdown]
# ## 3 Pre-Processing

# %% [markdown]
# #### Key Observations
#
# Claims
# - 13 categorical values, 6 numerical. However there are some cases where missing values in numerical values have "?" or "MISSINGVALUE" which is causing the feature to register as non numerical.
# - Data window is from 2015-01-01 to 2015-03-14.
# - Binary class labels N=No, Y=Yes.
# - Witnesses contains 46 values with 'MISSINGVALUE' removing these rows makes the most sense as it is an insignificant portion of the data.
# - 'TypeOfCollission' contains 5162 values of '?'
# - 'PropertyDamage' contains 10459 values of '?'
# - 'PoliceReport' contains 9805 values of '?'
# - 'IncedentTime' has some negative values which does not make sense, these rows will be dropped.
#
# Vehicles
# - Not much insight so far

# %% [markdown]
# #### Importing Initial Permitted Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn

# Library configurations
pd.set_option('display.max_columns', None)

# %% [markdown]
# #### Loading the Datasets into Pandas Dataframes for Analysis

# %%
# Storing the CSV files as variables
customers_withoutTarget_csv = "./Data/TrainData/Traindata_withoutTarget.csv"
customers_withTarget_csv = "./Data/TrainData/Traindata_with_Target.csv"
claims_csv = "./Data/TrainData/Train_Claim.csv"
demographics_csv = "./Data/TrainData/Train_Demographics.csv"
policy_csv = "./Data/TrainData/Train_Policy.csv"
vehicle_csv = "./Data/TrainData/Train_Vehicle.csv"

# Converting each of the CSV data to pandas dataframes
customers_no_target_df = pd.read_csv(customers_withoutTarget_csv)
customers_target_df = pd.read_csv(customers_withTarget_csv)
claims_df = pd.read_csv(claims_csv)
demographics_df = pd.read_csv(demographics_csv)
policy_df = pd.read_csv(policy_csv)
vehicle_df = pd.read_csv(vehicle_csv)

# Joining the data into one large dataframe for pre-processing
df1 = pd.merge(claims_df, demographics_df, on='CustomerID')
df2 = pd.merge(df1, policy_df, on='CustomerID')
full_df = pd.merge(df2, customers_target_df, on='CustomerID')

# %% [markdown]
# ### 3.1 Preparing the labels

# %% [markdown]
# #### 3.1.1 Dealing with class imbalance
# The following cell shows the class distributions, around 73% of the labels are non-fraudulant claims and around 27% fraudulant claims. Stratified sampling will be used when selecting the train and test sets to ensure the distribution stays consistant.

# %%
customers_target_df["ReportedFraud"].value_counts(normalize=True)
# Out:
# N    0.730025
# Y    0.269975
# Name: ReportedFraud, dtype: float64

# %%
from sklearn.model_selection import train_test_split

y = full_df["ReportedFraud"]
X = full_df.drop("ReportedFraud", axis=1)

# Splitting data and labels, stratify the datasets using the labels
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42, stratify=y)

# %%
# Confirming the labels have been correctly stratified
print(y_train.value_counts(normalize=True))
print(len(y_train))
# Out:
# N    0.730016
# Y    0.269984
# Name: ReportedFraud, dtype: float64
# 23068

# %%
y_test.value_counts(normalize=True)
print(len(y_test))
# Out:
# 5768

# %% [markdown]
# ### 3.2 Removing Synonymous and Noisy Atrributes

# %% [markdown]
# To Drop:
# - DateofIncident
# - TimeOfIncident

# %%
dropped_attributes = ["DateOfIncident", "TimeOfIncident"]
full_df.drop(dropped_attributes, axis=1)
# Out:
#       CustomerID            TypeOfIncident TypeOfCollission  \
# 0      Cust10000   Multi-vehicle Collision   Side Collision
# 1      Cust10001   Multi-vehicle Collision   Side Collision
# 2      Cust10002  Single Vehicle Collision   Side Collision
# 3      Cust10003  Single Vehicle Collision   Side Collision
# 4      Cust10004  Single Vehicle Collision   Rear Collision
# ...          ...                       ...              ...
# 28831   Cust9993             Vehicle Theft                ?
# 28832   Cust9994  Single Vehicle Collision  Front Collision
# 28833   Cust9996  Single Vehicle Collision   Rear Collision
# 28834   Cust9997  Single Vehicle Collision   Rear Collision
# 28835   Cust9999  Single Vehicle Collision  Front Collision
#
#       SeverityOfIncident AuthoritiesContacted IncidentState IncidentCity  \
# 0             Total Loss               Police        State7        City1
# 1             Total Loss               Police        State7        City5
# 2           Minor Damage                Other        State8        City6
# 3           Minor Damage                Other        State9        City6
# 4           Minor Damage                 Fire        State8        City6
# ...                  ...                  ...           ...          ...
# 28831     Trivial Damage               Police        State9        City4
# 28832       Minor Damage                 Fire        State8        City3
# 28833       Minor Damage                 Fire        State9        City7
# 28834       Minor Damage            Ambulance        State9        City3
# 28835         Total Loss                Other        State8        City3
#
#       IncidentAddress  IncidentTime  NumberOfVehicles PropertyDamage  \
# 0       Location 1311            17                 3              ?
# 1       Location 1311            10                 3            YES
# 2       Location 2081            22                 1            YES
# 3       Location 2081            22                 1            YES
# 4       Location 1695            10                 1             NO
# ...               ...           ...               ...            ...
# 28831   Location 1890             3                 1             NO
# 28832   Location 2097            17                 1            YES
# 28833   Location 1452             1                 1            YES
# 28834   Location 1876             1                 1              ?
# 28835   Location 1874             9                 1             NO
#
#        BodilyInjuries Witnesses PoliceReport AmountOfTotalClaim  \
# 0                   1         0            ?              65501
# 1                   2         1          YES              61382
# 2                   2         3           NO              66755
# 3                   2         3           NO              66243
# 4                   2         1          YES              53544
# ...               ...       ...          ...                ...
# 28831               0         3            ?               6590
# 28832               0         2          YES              74547
# 28833               2         0          YES              55305
# 28834               2         0          YES              55830
# 28835               1         3          YES              68969
#
#        AmountOfInjuryClaim  AmountOfPropertyClaim  AmountOfVehicleDamage  \
# 0                    13417                   6071                  46013
# 1                    15560                   5919                  39903
# 2                    11630                  11630                  43495
# 3                    12003                  12003                  42237
# 4                     8829                   7234                  37481
# ...                    ...                    ...                    ...
# 28831                  870                   1078                   4642
# 28832                14699                   7875                  51973
# 28833                 7043                   7043                  41219
# 28834                 7059                   7059                  41712
# 28835                12075                   6038                  50856
#
#        InsuredAge  InsuredZipCode InsuredGender InsuredEducationLevel  \
# 0              35          454776          MALE                    JD
# 1              36          454776          MALE                    JD
# 2              33          603260          MALE                    JD
# 3              36          474848          MALE                    JD
# 4              29          457942        FEMALE           High School
# ...           ...             ...           ...                   ...
# 28831          46          600561          MALE               Masters
# 28832          44          439304          MALE               Masters
# 28833          53          460722          MALE                   PhD
# 28834          53          472634          MALE             Associate
# 28835          36          450730        FEMALE                   PhD
#
#        InsuredOccupation InsuredHobbies  CapitalGains  CapitalLoss Country  \
# 0           armed-forces         movies         56700       -48500   India
# 1           tech-support      cross-fit         70600       -48500   India
# 2           armed-forces           polo         66400       -63700   India
# 3           armed-forces           polo         47900       -73400   India
# 4        exec-managerial        dancing             0       -41500   India
# ...                  ...            ...           ...          ...     ...
# 28831    protective-serv       sleeping             0            0   India
# 28832       adm-clerical        dancing             0       -28800   India
# 28833   transport-moving   base-jumping         63100       -43800   India
# 28834   transport-moving      skydiving         67400       -43800   India
# 28835  handlers-cleaners   base-jumping         46400       -74300   India
#
#        InsurancePolicyNumber  CustomerLoyaltyPeriod DateOfPolicyCoverage  \
# 0                     119121                     49           1998-10-25
# 1                     119122                    114           2000-11-15
# 2                     119123                    167           2001-02-12
# 3                     119124                    190           2005-04-11
# 4                     119125                    115           1996-10-25
# ...                      ...                    ...                  ...
# 28831                 119114                    321           1998-04-18
# 28832                 119115                    237           2004-09-07
# 28833                 119117                    392           1998-09-10
# 28834                 119118                    391           1998-08-10
# 28835                 119120                    191           2003-04-12
#
#       InsurancePolicyState Policy_CombinedSingleLimit  Policy_Deductible  \
# 0                   State1                    100/300               1000
# 1                   State1                    100/300               1000
# 2                   State3                   500/1000                617
# 3                   State2                   500/1000                722
# 4                   State2                    100/300                500
# ...                    ...                        ...                ...
# 28831               State1                   500/1000                655
# 28832               State2                    100/300               1089
# 28833               State3                    250/500                787
# 28834               State3                    250/500                780
# 28835               State2                   500/1000               2000
#
#        PolicyAnnualPremium  UmbrellaLimit InsuredRelationship ReportedFraud
# 0                  1632.73              0       not-in-family             N
# 1                  1255.19              0       not-in-family             N
# 2                  1373.38              0                wife             N
# 3                  1337.60              0           own-child             N
# 4                  1353.73        4279863           unmarried             N
# ...                    ...            ...                 ...           ...
# 28831              1276.01              0           unmarried             N
# 28832              1273.38              0           unmarried             N
# 28833              1380.92        3448735           own-child             N
# 28834              1389.29        3364301       not-in-family             N
# 28835               928.43        2909175             husband             N
#
# [28836 rows x 37 columns]

# %%
fraud = full_df["ReportedFraud"] == "Y"
full_df[fraud].head(20)
# Out:
#     CustomerID DateOfIncident            TypeOfIncident TypeOfCollission  \
# 9     Cust1001     2015-01-25  Single Vehicle Collision   Side Collision
# 33    Cust1004     2015-01-10  Single Vehicle Collision  Front Collision
# 39   Cust10046     2015-01-06  Single Vehicle Collision  Front Collision
# 50    Cust1006     2015-01-02   Multi-vehicle Collision   Rear Collision
# 59   Cust10073     2015-02-17                Parked Car                ?
# 67   Cust10084     2015-02-26   Multi-vehicle Collision   Rear Collision
# 93   Cust10112     2015-01-11  Single Vehicle Collision   Rear Collision
# 104  Cust10127     2015-02-14   Multi-vehicle Collision  Front Collision
# 106  Cust10129     2015-02-28  Single Vehicle Collision   Side Collision
# 108  Cust10131     2015-02-19  Single Vehicle Collision  Front Collision
# 124   Cust1015     2015-01-15  Single Vehicle Collision   Rear Collision
# 157  Cust10189     2015-02-08   Multi-vehicle Collision  Front Collision
# 192   Cust1023     2015-01-11   Multi-vehicle Collision   Rear Collision
# 200  Cust10239     2015-02-17  Single Vehicle Collision  Front Collision
# 217   Cust1026     2015-01-09   Multi-vehicle Collision   Rear Collision
# 222  Cust10268     2015-01-25  Single Vehicle Collision   Rear Collision
# 234   Cust1028     2015-01-07             Vehicle Theft                ?
# 240  Cust10289     2015-02-24  Single Vehicle Collision   Side Collision
# 260  Cust10316     2015-01-17   Multi-vehicle Collision  Front Collision
# 285  Cust10344     2015-02-23  Single Vehicle Collision   Side Collision
#
#     SeverityOfIncident AuthoritiesContacted IncidentState IncidentCity  \
# 9         Major Damage               Police        State7        City2
# 33        Major Damage               Police        State3        City1
# 39        Minor Damage               Police        State5        City2
# 50        Major Damage                 Fire        State7        City1
# 59      Trivial Damage               Police        State9        City2
# 67        Major Damage               Police        State8        City1
# 93        Major Damage               Police        State7        City5
# 104         Total Loss            Ambulance        State9        City1
# 106         Total Loss                Other        State8        City2
# 108       Minor Damage                Other        State5        City2
# 124         Total Loss               Police        State7        City7
# 157       Minor Damage                 Fire        State9        City2
# 192       Major Damage            Ambulance        State7        City3
# 200         Total Loss                Other        State7        City5
# 217       Major Damage                Other        State3        City1
# 222         Total Loss            Ambulance        State9        City4
# 234       Minor Damage                 None        State8        City5
# 240         Total Loss                Other        State7        City6
# 260         Total Loss                 Fire        State5        City1
# 285         Total Loss                Other        State7        City7
#
#     IncidentAddress  IncidentTime  NumberOfVehicles PropertyDamage  \
# 9     Location 1596             5                 1            YES
# 33    Location 2054             5                 1              ?
# 39    Location 1060            15                 1             NO
# 50    Location 2051            19                 3             NO
# 59    Location 1943             7                 1              ?
# 67    Location 1517            13                 3              ?
# 93    Location 1935            17                 1             NO
# 104   Location 1330            15                 4            YES
# 106   Location 1677            12                 1              ?
# 108   Location 1346             7                 1              ?
# 124   Location 1995            12                 1             NO
# 157   Location 1288            19                 3             NO
# 192   Location 1652            20                 3             NO
# 200   Location 1659             8                 1              ?
# 217   Location 1168            16                 3             NO
# 222   Location 1227            21                 1            YES
# 234   Location 1747             5                 1            YES
# 240   Location 1027            10                 2             NO
# 260   Location 1262             4                 3              ?
# 285   Location 1423             8                 1             NO
#
#      BodilyInjuries Witnesses PoliceReport AmountOfTotalClaim  \
# 9                 1         2          YES              71610
# 33                1         2           NO              63400
# 39                2         2          YES              78737
# 50                0         2           NO              64100
# 59                0         1          YES               3197
# 67                0         3          YES              65046
# 93                2         0            ?              57180
# 104               1         2          YES              55162
# 106               1         0          YES              61577
# 108               2         3          YES              54547
# 124               0         2          YES              46200
# 157               2         2           NO              57550
# 192               0         0          YES              71520
# 200               0         1            ?              70114
# 217               1         3          YES              71500
# 222               1         3          YES              84272
# 234               2         1            ?               5720
# 240               0         3          YES              70836
# 260               0         3           NO              45434
# 285               0         3          YES              67125
#
#      AmountOfInjuryClaim  AmountOfPropertyClaim  AmountOfVehicleDamage  \
# 9                   6510                  13020                  52080
# 33                  6340                   6340                  50720
# 39                 10717                  13762                  54258
# 50                  6410                   6410                  51280
# 59                   581                    292                   2324
# 67                  8094                   8094                  48858
# 93                  6319                   6630                  44231
# 104                 6927                   5174                  43061
# 106                 6232                   6067                  49278
# 108                 8616                   7748                  38183
# 124                 4200                   8400                  33600
# 157                 9466                   9466                  38618
# 192                17880                   5960                  47680
# 200                12753                   6349                  51012
# 217                16500                  11000                  44000
# 222                15462                  14692                  54118
# 234                 1040                    520                   4160
# 240                 9919                  12424                  48493
# 260                 4543                   5490                  35401
# 285                10249                  10249                  46627
#
#      InsuredAge  InsuredZipCode InsuredGender InsuredEducationLevel  \
# 9            48          466132          MALE                    MD
# 33           41          608117        FEMALE                   PhD
# 39           32          431361        FEMALE               Masters
# 50           39          478456        FEMALE                   PhD
# 59           27          439787        FEMALE           High School
# 67           33          441726          MALE               Masters
# 93           41          464145        FEMALE               College
# 104          41          601117        FEMALE                    JD
# 106          44          462836        FEMALE                   PhD
# 108          31          612664          MALE               College
# 124          38          476685        FEMALE               College
# 157          38          617699        FEMALE           High School
# 192          55          443920          MALE           High School
# 200          33          461744        FEMALE                   PhD
# 217          35          613982          MALE               Masters
# 222          27          464743        FEMALE                    JD
# 234          34          607730          MALE                    JD
# 240          43          459878          MALE               College
# 260          35          462106        FEMALE           High School
# 285          42          473935          MALE               College
#
#      InsuredOccupation  InsuredHobbies  CapitalGains  CapitalLoss Country  \
# 9         craft-repair        sleeping         53300            0   India
# 33        armed-forces     board-games         48900       -62400   India
# 39   machine-op-inspct    base-jumping             0            0   India
# 50        tech-support  bungie-jumping             0            0   India
# 59      prof-specialty        kayaking             0            0   India
# 67   handlers-cleaners        exercise             0            0   India
# 93        tech-support           chess             0            0   India
# 104   transport-moving        sleeping             0       -67400   India
# 106    priv-house-serv        yachting         83200            0   India
# 108    priv-house-serv        exercise         67900            0   India
# 124  machine-op-inspct     board-games         41300       -55500   India
# 157    farming-fishing        yachting         53000            0   India
# 192     prof-specialty       paintball         72700       -68200   India
# 200  handlers-cleaners        kayaking             0       -40900   India
# 217              sales            polo             0            0   India
# 222      other-service       skydiving         31500            0   India
# 234    exec-managerial           chess         31000       -30200   India
# 240       craft-repair       skydiving         23300            0   India
# 260   transport-moving     board-games             0            0   India
# 285       craft-repair        exercise             0            0   India
#
#      InsurancePolicyNumber  CustomerLoyaltyPeriod DateOfPolicyCoverage  \
# 9                   110122                    328           2014-10-17
# 33                  110125                    256           1990-05-25
# 39                  119167                    147           2009-07-21
# 50                  110127                    256           2006-10-12
# 59                  119194                      7           1992-08-05
# 67                  119205                    181           1993-10-19
# 93                  119233                    251           2004-04-20
# 104                 119248                    228           2009-03-07
# 106                 119250                    292           1997-02-28
# 108                 119252                    123           2011-05-21
# 124                 110136                    180           1998-12-28
# 157                 119310                    234           2000-12-01
# 192                 110144                    370           1994-05-27
# 200                 119360                    106           1996-07-08
# 217                 110147                      8           2013-12-05
# 222                 119389                     30           2013-07-27
# 234                 110149                    202           2002-07-18
# 240                 119410                    246           2008-04-04
# 260                 119437                    142           2005-09-09
# 285                 119465                    250           2011-08-12
#
#     InsurancePolicyState Policy_CombinedSingleLimit  Policy_Deductible  \
# 9                 State3                    250/500               1000
# 33                State1                    250/500               2000
# 39                State1                    100/300               2000
# 50                State3                    250/500               1000
# 59                State3                    250/500                502
# 67                State3                   500/1000               1050
# 93                State2                    100/300               1000
# 104               State2                    250/500               2000
# 106               State3                   500/1000                500
# 108               State3                    100/300                500
# 124               State3                    250/500               2000
# 157               State3                    100/300               1000
# 192               State1                    100/300               2000
# 200               State1                   500/1000                500
# 217               State3                    100/300               2000
# 222               State1                    250/500               1869
# 234               State2                    100/300                500
# 240               State1                    100/300                690
# 260               State2                   500/1000                577
# 285               State1                    100/300                500
#
#      PolicyAnnualPremium  UmbrellaLimit InsuredRelationship ReportedFraud
# 9                1406.91              0             husband             Y
# 33               1415.74        6000000           unmarried             Y
# 39               1057.90              0           unmarried             Y
# 50               1351.10              0           unmarried             Y
# 59               1075.95              0           unmarried             Y
# 67               1242.58              0             husband             Y
# 93               1421.59              0       not-in-family             Y
# 104              1158.84        6033190           own-child             Y
# 106              1099.07              0       not-in-family             Y
# 108              1390.85              0                wife             Y
# 124              1301.13              0       not-in-family             Y
# 157              1222.27        4799340       not-in-family             Y
# 192               972.18              0      other-relative             Y
# 200              1309.87          51560           own-child             Y
# 217              1266.92              0           own-child             Y
# 222              1144.41              0       not-in-family             Y
# 234               848.07        3000000       not-in-family             Y
# 240                -1.00              0           own-child             Y
# 260              1019.97              0           unmarried             Y
# 285              1315.80        2057567           own-child             Y

# %%
not_fraud = full_df["ReportedFraud"] == "N"
full_df[not_fraud].head(20)
# Out:
#    CustomerID DateOfIncident            TypeOfIncident TypeOfCollission  \
# 0   Cust10000     2015-02-03   Multi-vehicle Collision   Side Collision
# 1   Cust10001     2015-02-02   Multi-vehicle Collision   Side Collision
# 2   Cust10002     2015-01-15  Single Vehicle Collision   Side Collision
# 3   Cust10003     2015-01-19  Single Vehicle Collision   Side Collision
# 4   Cust10004     2015-01-09  Single Vehicle Collision   Rear Collision
# 5   Cust10005     2015-02-07  Single Vehicle Collision   Rear Collision
# 6   Cust10006     2015-01-30  Single Vehicle Collision  Front Collision
# 7   Cust10007     2015-01-12  Single Vehicle Collision  Front Collision
# 8   Cust10009     2015-02-06   Multi-vehicle Collision  Front Collision
# 10  Cust10011     2015-02-10  Single Vehicle Collision   Rear Collision
# 11  Cust10012     2015-02-22   Multi-vehicle Collision   Side Collision
# 12  Cust10013     2015-02-25   Multi-vehicle Collision   Side Collision
# 13  Cust10014     2015-01-02   Multi-vehicle Collision   Rear Collision
# 14  Cust10016     2015-02-28   Multi-vehicle Collision   Side Collision
# 15  Cust10017     2015-02-28   Multi-vehicle Collision   Side Collision
# 16  Cust10018     2015-02-28                Parked Car                ?
# 17  Cust10019     2015-02-28                Parked Car                ?
# 18  Cust10021     2015-01-03             Vehicle Theft                ?
# 19  Cust10022     2015-01-29  Single Vehicle Collision  Front Collision
# 20  Cust10023     2015-02-23  Single Vehicle Collision  Front Collision
#
#    SeverityOfIncident AuthoritiesContacted IncidentState IncidentCity  \
# 0          Total Loss               Police        State7        City1
# 1          Total Loss               Police        State7        City5
# 2        Minor Damage                Other        State8        City6
# 3        Minor Damage                Other        State9        City6
# 4        Minor Damage                 Fire        State8        City6
# 5        Minor Damage                 Fire        State7        City6
# 6        Minor Damage            Ambulance        State5        City4
# 7        Minor Damage               Police        State5        City3
# 8        Minor Damage            Ambulance        State9        City2
# 10       Minor Damage                 Fire        State9        City5
# 11       Major Damage                Other        State7        City1
# 12       Major Damage                Other        State7        City2
# 13       Minor Damage               Police        State5        City2
# 14         Total Loss                Other        State7        City2
# 15         Total Loss                Other        State7        City2
# 16       Minor Damage               Police        State6        City1
# 17       Minor Damage               Police        State6        City1
# 18     Trivial Damage                 None        State4        City5
# 19       Minor Damage            Ambulance        State8        City4
# 20       Minor Damage            Ambulance        State8        City4
#
#    IncidentAddress  IncidentTime  NumberOfVehicles PropertyDamage  \
# 0    Location 1311            17                 3              ?
# 1    Location 1311            10                 3            YES
# 2    Location 2081            22                 1            YES
# 3    Location 2081            22                 1            YES
# 4    Location 1695            10                 1             NO
# 5    Location 1695             7                 1             NO
# 6    Location 1440            20                 1              ?
# 7    Location 1440            18                 1              ?
# 8    Location 1521             3                 3            YES
# 10   Location 2002            14                 1             NO
# 11   Location 1341            16                 3            YES
# 12   Location 1799            15                 3            YES
# 13   Location 2030            20                 3             NO
# 14   Location 1677            13                 1             NO
# 15   Location 1677            12                 1              ?
# 16   Location 1963             7                 1            YES
# 17   Location 1963             7                 1            YES
# 18   Location 1449            10                 1              ?
# 19   Location 1580            13                 1              ?
# 20   Location 1167             9                 1              ?
#
#     BodilyInjuries Witnesses PoliceReport AmountOfTotalClaim  \
# 0                1         0            ?              65501
# 1                2         1          YES              61382
# 2                2         3           NO              66755
# 3                2         3           NO              66243
# 4                2         1          YES              53544
# 5                1         2            ?              53167
# 6                0         2           NO              77453
# 7                0         2           NO              60569
# 8                0         0            ?              67876
# 10               0         0            ?              58293
# 11               1         0          YES              50631
# 12               1         0          YES              57120
# 13               1         0            ?              48939
# 14               1         0          YES              60854
# 15               1         0          YES              61697
# 16               0         2           NO               5371
# 17               0         2          YES               5408
# 18               2         1            ?               6190
# 19               1         1          YES              56357
# 20               1         3          YES              61780
#
#     AmountOfInjuryClaim  AmountOfPropertyClaim  AmountOfVehicleDamage  \
# 0                 13417                   6071                  46013
# 1                 15560                   5919                  39903
# 2                 11630                  11630                  43495
# 3                 12003                  12003                  42237
# 4                  8829                   7234                  37481
# 5                  7818                   8132                  37217
# 6                  6476                  12822                  58155
# 7                  5738                   7333                  47498
# 8                  6788                   7504                  53584
# 10                 9396                   5433                  43464
# 11                10110                   5055                  35466
# 12                10593                   5297                  41230
# 13                 1079                   5797                  42063
# 14                 6596                   5461                  48797
# 15                 6172                   6167                  49358
# 16                  679                    521                   4171
# 17                  689                    524                   4195
# 18                  619                   1208                   4363
# 19                 6084                   6084                  44189
# 20                 6276                   6276                  49228
#
#     InsuredAge  InsuredZipCode InsuredGender InsuredEducationLevel  \
# 0           35          454776          MALE                    JD
# 1           36          454776          MALE                    JD
# 2           33          603260          MALE                    JD
# 3           36          474848          MALE                    JD
# 4           29          457942        FEMALE           High School
# 5           28          457942        FEMALE           High School
# 6           57          476456          MALE               Masters
# 7           49          476456          MALE               Masters
# 8           27          432896        FEMALE           High School
# 10          41          455810        FEMALE                    MD
# 11          36          446544        FEMALE             Associate
# 12          36          446544        FEMALE             Associate
# 13          59          618845          MALE               College
# 14          44          462836        FEMALE                   PhD
# 15          44          615383        FEMALE                   PhD
# 16          33          608425          MALE           High School
# 17          33          608425          MALE                    MD
# 18          40          603123        FEMALE               Masters
# 19          44          450889        FEMALE             Associate
# 20          39          601425        FEMALE             Associate
#
#     InsuredOccupation InsuredHobbies  CapitalGains  CapitalLoss Country  \
# 0        armed-forces         movies         56700       -48500   India
# 1        tech-support      cross-fit         70600       -48500   India
# 2        armed-forces           polo         66400       -63700   India
# 3        armed-forces           polo         47900       -73400   India
# 4     exec-managerial        dancing             0       -41500   India
# 5     exec-managerial        dancing             0       -41500   India
# 6        adm-clerical       sleeping         67400            0   India
# 7        adm-clerical       sleeping         67400            0   India
# 8   handlers-cleaners        camping         56400       -32800   India
# 10     prof-specialty           golf         58100       -65600   India
# 11       craft-repair      paintball             0            0   India
# 12       craft-repair   base-jumping             0            0   India
# 13      other-service         movies         30400            0   India
# 14    priv-house-serv       yachting             0            0   India
# 15    priv-house-serv     basketball             0       -53300   India
# 16     prof-specialty           polo             0       -29200   India
# 17     prof-specialty           polo             0       -29200   India
# 18    exec-managerial        dancing             0            0   India
# 19       adm-clerical         hiking         73000       -37900   India
# 20       tech-support         hiking         38700       -37900   India
#
#     InsurancePolicyNumber  CustomerLoyaltyPeriod DateOfPolicyCoverage  \
# 0                  119121                     49           1998-10-25
# 1                  119122                    114           2000-11-15
# 2                  119123                    167           2001-02-12
# 3                  119124                    190           2005-04-11
# 4                  119125                    115           1996-10-25
# 5                  119126                    101           1999-10-24
# 6                  119127                    471           1995-02-18
# 7                  119128                    340           1993-02-22
# 8                  119130                     81           1998-05-09
# 10                 119132                    241           2012-12-11
# 11                 119133                    208           2000-06-18
# 12                 119134                    216           1999-06-12
# 13                 119135                    425           2003-06-24
# 14                 119137                    289           1998-03-27
# 15                 119138                    292           1997-02-28
# 16                 119139                    171           2001-11-18
# 17                 119140                    171           2001-11-18
# 18                 119142                    234           1998-08-05
# 19                 119143                    269           2002-07-26
# 20                 119144                    223           2010-07-13
#
#    InsurancePolicyState Policy_CombinedSingleLimit  Policy_Deductible  \
# 0                State1                    100/300               1000
# 1                State1                    100/300               1000
# 2                State3                   500/1000                617
# 3                State2                   500/1000                722
# 4                State2                    100/300                500
# 5                State2                    100/300                500
# 6                State3                    100/300                512
# 7                State3                    100/300                877
# 8                State2                   500/1000               2000
# 10               State3                    100/300                500
# 11               State1                    250/500                511
# 12               State1                    250/500               1044
# 13               State3                    250/500               1000
# 14               State3                   500/1000                500
# 15               State3                   500/1000                500
# 16               State2                    100/300               1193
# 17               State2                    100/300               1201
# 18               State1                   250/1000               2000
# 19               State3                   500/1000               1620
# 20               State3                   500/1000                745
#
#     PolicyAnnualPremium  UmbrellaLimit InsuredRelationship ReportedFraud
# 0               1632.73              0       not-in-family             N
# 1               1255.19              0       not-in-family             N
# 2               1373.38              0                wife             N
# 3               1337.60              0           own-child             N
# 4               1353.73        4279863           unmarried             N
# 5               1334.49        3921366           unmarried             N
# 6               1214.78         165819           own-child             N
# 7               1159.81        5282219           own-child             N
# 8                989.53              0           own-child             N
# 10              1250.38              0      other-relative             N
# 11              1153.91              0       not-in-family             N
# 12              1174.75              0      other-relative             N
# 13              1226.36        3602013      other-relative             N
# 14              1107.90              0           unmarried             N
# 15              1097.61              0           unmarried             N
# 16              1338.18              0           own-child             N
# 17              1338.02              0           own-child             N
# 18              1272.75        5216321                wife             N
# 19              1194.89              0           own-child             N
# 20              1408.03              0           own-child             N

# %% [markdown]
# #### 3.2.1 Identifying Key Attributes (SeverityOfIncident)
# One of my first observations when viewing the data was that confirmed fraudulant cases where often "Major Damage" cases while legitimate cases where "Total Loss" or minimal damage cases. This will be illustrated in the next cell with a histogram, showing a very clear difference in total cases between the two classes.

# %%
soi_fraud = full_df[fraud]["SeverityOfIncident"]
soi_not_fraud = full_df[not_fraud]["SeverityOfIncident"]
colors = ["Red", "Blue"]
label = ["Fraud", "Not-Fraud"]
title = "Severity levels for confirmed and non confirmed fraud"
x = [soi_fraud, soi_not_fraud]
plt.title(title)
plt.hist(x, 4, density=True, histtype="bar", color=colors)
plt.xlabel('Severity Level')
plt.ylabel('Total Cases')
plt.legend(label)
plt.show()

# %% [markdown]
# #### 3.2.2 Identifying Key Attributes ( )

# %%
inctime_fraud = full_df[fraud]["IncidentTime"]
inctime_not_fraud = full_df[not_fraud]["IncidentTime"]
colors = ["Red", "Blue"]
label = ["Fraud", "Not-Fraud"]
title = "Incident Time for confirmed and non confirmed fraud"
x = [inctime_fraud, inctime_not_fraud]
plt.title(title)
plt.hist(x, 25, density=True, histtype="bar", color=colors, stacked=True)
plt.xlabel('Severity Level')
plt.ylabel('Total Cases')
plt.legend(label)
plt.show()

# %% [markdown]
# ### 3.3 Dealing with Missing Values

# %%
#missed_data = full_df["AmountOfTotalClaim"] == "MISSEDDATA"
#full_df[missed_data].head(50)

# %% [markdown]
# ### 3.4 Dealing with duplicate values

# %% [markdown]
# ### 3.5 Rescaling

# %% [markdown]
# ### 3.6 Dealing with Class Imbalance

# %% [markdown]
# ### 3.7 Dealing with Collinearity

# %% [markdown]
# ## 4 Technique 1 - Classification, Decision Tree

# %% [markdown]
# ## 5 Technique 2 - Classification, Logistic Regression
