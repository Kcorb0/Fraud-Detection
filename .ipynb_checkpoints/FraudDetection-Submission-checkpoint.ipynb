# %% [markdown]
# # Assignment 2: Fraud Detection

# %% [markdown]
# Author: Josh NM Blackmore <br>
# StID: 201776628

# %% [markdown]
# ## Case Study
#
# <p>An insurance company plans to utilise their historic insurance fraud dataset to predict the likelihood or the level of risk a customer poses. You can find the dataset above. Referring genuine claims cause customer stress and directly leads to customer loss, costing the company money (assume that any referred non-fraud case will lead to losing that customer). While obviously, fraud claims cost the company as well. Their main requirement is to use an unbiased predictive model capable of flagging and referring potential fraud cases for further investigation with a balanced error rate of 5%.</p>

# %% [markdown]
# ## 1 Aims, Objectives & Plan
# ### 1.1 Aims & Objectives
# This projects primary objective is to analyse a medium sized dataset containing insurance claims from an insurance company with the goal of identifying potential fraudulant claims. The project requires a minumum of two techniques to provide predictions or valuable insights.
#
# Provided datasets will be pre-processed with various techniques and the reasoning behind certain decisions.
#
# Secondly, a technical report which consists of a narration around the analysis conducted for the project. This will be a jupyter notebook document containing the key procedures taken for each step such as justifying choices made in pre-processing, the models solutions, various visualisations of the analysis and testing with performance metrics such as F1, recall, confusion matrix etc.
#
# ### 1.2 Plan
# - Gantt Chart

# %% [markdown]
# ## 2 Understanding the Case Study
# ### 2.1 Case Study Analysis
# In this section I will present my understanding of the case study with the 4 critical points found in the case description.
# #### 2.1.1 Predicting a Customers Level of Risk
# Each row of the datasets provide information for an individual customers claim with labels depicting if the claim was fraudulant or legitimate. The client needs to know what level of risk future clients pose for future cases, using historical data.
#
# #### 2.1.2 Cost of Fraudulant Cases for Customers and Company
# Cases provided contain various cost factors such as property claim, injury claims etc. Part of the case study specifies the need to highlight the cost risk for fraudulant cases company and customer alike, the case study specifies the risk of losing customers due to cost.
#
# #### 2.1.3 Unbiased Prediction Model to Flag Fraudulant Cases
# The case study specifies the need of unbiased predictions. This can be acheived in pre-processing ensuring the training/test data is well balanced with fair distributions. Techniques such as regularization and post-processing techniques such as equalizing false positives and false negatives.
#
# #### 2.1.4 Accuracy and Error Rate of the Models
# Accuracy measures are needed to ensure the model is making correct predictions/accurate insights, such as correctly classified instances. The error rate will also be calculated to complement accuracy. The case study specifies the client is expecting a balanced error rate of around 5%.

# %% [markdown]
# ## 3 Pre-Processing

# %% [markdown]
# #### Key Observations
#
# Claims
# - 13 categorical values, 6 numerical. However there are some cases where missing values in numerical values have "?" or "MISSINGVALUE" which is causing the feature to register as non numerical.
# - Data window is from 2015-01-01 to 2015-03-14.
# - Binary class labels N=No, Y=Yes.
# - Witnesses contains 46 values with 'MISSINGVALUE' removing these rows makes the most sense as it is an insignificant portion of the data.
# - 'TypeOfCollission' contains 5162 values of '?'
# - 'PropertyDamage' contains 10459 values of '?'
# - 'PoliceReport' contains 9805 values of '?'
# - 'IncedentTime' has some negative values which does not make sense, these rows will be dropped.
#
# Vehicles
# - Not much insight so far

# %% [markdown]
# #### Importing Initial Permitted Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn

# Library configurations
pd.set_option('display.max_columns', None)

# %% [markdown]
# #### Loading the Datasets into Pandas Dataframes for Analysis

# %%
# Storing the CSV files as variables
customers_withoutTarget_csv = "./Data/TrainData/Traindata_withoutTarget.csv"
customers_withTarget_csv = "./Data/TrainData/Traindata_with_Target.csv"
claims_csv = "./Data/TrainData/Train_Claim.csv"
demographics_csv = "./Data/TrainData/Train_Demographics.csv"
policy_csv = "./Data/TrainData/Train_Policy.csv"
vehicle_csv = "./Data/TrainData/Train_Vehicle.csv"

# Converting each of the CSV data to pandas dataframes
customers_no_target_df = pd.read_csv(customers_withoutTarget_csv)
customers_target_df = pd.read_csv(customers_withTarget_csv)
claims_df = pd.read_csv(claims_csv)
demographics_df = pd.read_csv(demographics_csv)
policy_df = pd.read_csv(policy_csv)
vehicle_df = pd.read_csv(vehicle_csv)

# Joining the data into one large dataframe for pre-processing
df1 = pd.merge(claims_df, demographics_df, on='CustomerID')
df2 = pd.merge(df1, policy_df, on='CustomerID')
full_df = pd.merge(df2, customers_target_df, on='CustomerID')

fraud = full_df["ReportedFraud"] == "Y"
not_fraud = full_df["ReportedFraud"] == "N"

# %% [markdown]
# ### 3.1 Preparing the labels

# %% [markdown]
# #### 3.1.1 Dealing with class imbalance
# The following cell shows the class distributions, around 73% of the labels are non-fraudulant claims and around 27% fraudulant claims. Stratified sampling will be used when selecting the train and test sets to ensure the distribution stays consistant.

# %%
customers_target_df["ReportedFraud"].value_counts(normalize=True)
# Out:
# N    0.730025
# Y    0.269975
# Name: ReportedFraud, dtype: float64

# %%
from sklearn.model_selection import train_test_split

y = full_df["ReportedFraud"]
X = full_df.drop("ReportedFraud", axis=1)

# Splitting data and labels, stratify the datasets using the labels
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42, stratify=y)

# %%
# Confirming the labels have been correctly stratified
print(y_train.value_counts(normalize=True))
print(len(y_train))
# Out:
# N    0.730016
# Y    0.269984
# Name: ReportedFraud, dtype: float64
# 23068

# %%
y_test.value_counts(normalize=True)
print(len(y_test))
# Out:
# 5768

# %% [markdown]
# ### 3.2 Removing Synonymous and Noisy Atrributes

# %% [markdown]
# Key Attributes:
# - SeverityOfIncident
# - AuthoritiesContacted
# - Witnesses - Remove missingdata rows, theres only a few
# - AmountOfTotalClaim
# - AmountOfInjuryClaim
# - AmountOfPropertyClaim
# - AmountOfVehicleDamage
#
# To Drop:
# - DateofIncident
# - TimeOfIncident
# - Locations
# - PoliceReport
# - Country: All india and some missing values with no visible pattern for fraud or not fraud
# - UmbrellaLimit too many 0 values that may cause bias, may explore replacing these values later

# %%
dropped_attributes = ["CustomerID",
                      "DateOfIncident",
                      "TypeOfIncident", 
                      "TypeOfCollission", 
                      "IncidentState", 
                      "IncidentCity", 
                      "IncidentAddress",
                      "PoliceReport",
                      "Country",
                      "InsuredGender",
                      "UmbrellaLimit",
                      "InsurancePolicyState",
                      "InsuredEducationLevel"]

x_train = x_train.drop(dropped_attributes, axis=1)
x_train.head(5)
# Out:
#       SeverityOfIncident AuthoritiesContacted  IncidentTime  NumberOfVehicles  \
# 20936       Major Damage                 Fire             4                 3
# 19307       Minor Damage                Other            19                 3
# 2609      Trivial Damage                 None             8                 1
# 15420         Total Loss                Other             4                 2
# 21007       Minor Damage                 Fire            14                 1
#
#       PropertyDamage  BodilyInjuries Witnesses AmountOfTotalClaim  \
# 20936              ?               2         1              50565
# 19307              ?               2         0              53301
# 2609               ?               2         2               3922
# 15420              ?               2         0              88690
# 21007             NO               0         0              62271
#
#        AmountOfInjuryClaim  AmountOfPropertyClaim  AmountOfVehicleDamage  \
# ...

# %% [markdown]
# #### 3.2.1 Identifying Key Attributes (SeverityOfIncident)
# One of my first observations when viewing the data was that confirmed fraudulant cases where often "Major Damage" cases while legitimate cases where "Total Loss" or minimal damage cases. This will be illustrated in the next cell with a histogram, showing a very clear difference in total cases between the two classes.

# %%
soi_fraud = full_df[fraud]["SeverityOfIncident"]
soi_not_fraud = full_df[not_fraud]["SeverityOfIncident"]
colors = ["Red", "Blue"]
label = ["Fraud", "Not-Fraud"]
title = "Severity levels for confirmed and non confirmed fraud"
x = [soi_fraud, soi_not_fraud]
plt.title(title)
plt.hist(x, 4, density=True, histtype="bar", color=colors)
plt.xlabel('Severity Level')
plt.ylabel('Total Cases')
plt.legend(label)
plt.show()

# %% [markdown]
# #### 3.2.2 Identifying Key Attributes (AuthoritiesContacted)
# Fraudulent cases tend to call departments other than police however there are a small number of cases where fraud cases are not reported, which makes sense concidering how fraud tends to work.

# %%
auth_fraud = full_df[fraud]["AuthoritiesContacted"]
auth_not_fraud = full_df[not_fraud]["AuthoritiesContacted"]
colors = ["Red", "Blue"]
label = ["Fraud", "Not-Fraud"]
title = "Type of authorities contacted to the scene."
x = [auth_fraud, auth_not_fraud]
plt.title(title)
plt.hist(x, 5, density=True, histtype="bar", color=colors, stacked=False)
plt.legend(label)
plt.show()

# %% [markdown]
# #### 3.2.3 Identifying Key Attributes (InsuredHobbies)
# - Some outstanding hobbies, but no strong patterns

# %%
hobbies_fraud = full_df[fraud]["InsuredHobbies"]
hobbies_not_fraud = full_df[not_fraud]["InsuredHobbies"]
colors = ["Red", "Blue"]
label = ["Fraud", "Not-Fraud"]
x = [hobbies_fraud, hobbies_not_fraud]

plt.figure(figsize=(30,10))
plt.hist(x, 20, density=False, histtype="bar", color=colors, stacked=False)
plt.legend(label)
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
corr = full_df.corr(method="spearman")

plt.matshow(corr)
plt.show()
# Out:
# /tmp/ipykernel_17539/539407131.py:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = full_df.corr(method="spearman")

# %%
claim_amounts = ["AmountOfTotalClaim", 
                 "AmountOfInjuryClaim", 
                 "AmountOfPropertyClaim", 
                 "AmountOfVehicleDamage"]

missed_data = full_df["AmountOfTotalClaim"] != "MISSEDDATA"
nodata = full_df[missed_data]

nodata["AmountOfTotalClaim"] = nodata["AmountOfTotalClaim"].astype('int')

claim_amounts_fraud = nodata[fraud][claim_amounts]
claim_amounts_not_fraud = nodata[not_fraud][claim_amounts]


colors = ["Red", "Blue"]
label = ["Fraud", "Not-Fraud"]

claim_amounts_fraud.hist()
# Out:
# /tmp/ipykernel_17539/55450211.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nodata["AmountOfTotalClaim"] = nodata["AmountOfTotalClaim"].astype('int')
# /tmp/ipykernel_17539/55450211.py:11: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   claim_amounts_fraud = nodata[fraud][claim_amounts]
# /tmp/ipykernel_17539/55450211.py:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   claim_amounts_not_fraud = nodata[not_fraud][claim_amounts]
# array([[<Axes: title={'center': 'AmountOfTotalClaim'}>,
#         <Axes: title={'center': 'AmountOfInjuryClaim'}>],
#        [<Axes: title={'center': 'AmountOfPropertyClaim'}>,
# ...

# %%
from pandas.plotting import scatter_matrix

scatter_matrix(claim_amounts_not_fraud, figsize=(10,10))
# Out:
# array([[<Axes: xlabel='AmountOfTotalClaim', ylabel='AmountOfTotalClaim'>,
#         <Axes: xlabel='AmountOfInjuryClaim', ylabel='AmountOfTotalClaim'>,
#         <Axes: xlabel='AmountOfPropertyClaim', ylabel='AmountOfTotalClaim'>,
#         <Axes: xlabel='AmountOfVehicleDamage', ylabel='AmountOfTotalClaim'>],
#        [<Axes: xlabel='AmountOfTotalClaim', ylabel='AmountOfInjuryClaim'>,
#         <Axes: xlabel='AmountOfInjuryClaim', ylabel='AmountOfInjuryClaim'>,
#         <Axes: xlabel='AmountOfPropertyClaim', ylabel='AmountOfInjuryClaim'>,
#         <Axes: xlabel='AmountOfVehicleDamage', ylabel='AmountOfInjuryClaim'>],
#        [<Axes: xlabel='AmountOfTotalClaim', ylabel='AmountOfPropertyClaim'>,
#         <Axes: xlabel='AmountOfInjuryClaim', ylabel='AmountOfPropertyClaim'>,
#         <Axes: xlabel='AmountOfPropertyClaim', ylabel='AmountOfPropertyClaim'>,
#         <Axes: xlabel='AmountOfVehicleDamage', ylabel='AmountOfPropertyClaim'>],
# ...

# %%
scatter_matrix(claim_amounts_fraud, figsize=(10,10))
# Out:
# array([[<Axes: xlabel='AmountOfTotalClaim', ylabel='AmountOfTotalClaim'>,
#         <Axes: xlabel='AmountOfInjuryClaim', ylabel='AmountOfTotalClaim'>,
#         <Axes: xlabel='AmountOfPropertyClaim', ylabel='AmountOfTotalClaim'>,
#         <Axes: xlabel='AmountOfVehicleDamage', ylabel='AmountOfTotalClaim'>],
#        [<Axes: xlabel='AmountOfTotalClaim', ylabel='AmountOfInjuryClaim'>,
#         <Axes: xlabel='AmountOfInjuryClaim', ylabel='AmountOfInjuryClaim'>,
#         <Axes: xlabel='AmountOfPropertyClaim', ylabel='AmountOfInjuryClaim'>,
#         <Axes: xlabel='AmountOfVehicleDamage', ylabel='AmountOfInjuryClaim'>],
#        [<Axes: xlabel='AmountOfTotalClaim', ylabel='AmountOfPropertyClaim'>,
#         <Axes: xlabel='AmountOfInjuryClaim', ylabel='AmountOfPropertyClaim'>,
#         <Axes: xlabel='AmountOfPropertyClaim', ylabel='AmountOfPropertyClaim'>,
#         <Axes: xlabel='AmountOfVehicleDamage', ylabel='AmountOfPropertyClaim'>],
# ...

# %%
colors = ["Red", "Blue"]
label = ["Fraud", "Not-Fraud"]
title = "Type of authorities contact to the scene."
x = [claim_amounts_fraud["AmountOfTotalClaim"], claim_amounts_not_fraud["AmountOfTotalClaim"]]
#plt.title(title)
plt.hist(x, 100, density=True, histtype="bar", color=colors, stacked=True)
plt.legend(label)
plt.show()

# %%
hobbies_fraud = full_df[fraud]["InsuredHobbies"]
hobbies_not_fraud = full_df[not_fraud]["InsuredHobbies"]
colors = ["Red", "Blue"]
label = ["Fraud", "Not-Fraud"]
x = [hobbies_fraud, hobbies_not_fraud]

plt.figure(figsize=(30,10))
plt.hist(x, 20, density=False, histtype="bar", color=colors, stacked=False)
plt.legend(label)
plt.show()

# %% [markdown]
# ### 3.3 Dealing with Missing Values

# %%
inctime_missing = x_train[x_train["IncidentTime"] == -5].index
x_train, y_train = x_train.drop(inctime_missing), y_train.drop(inctime_missing)

# %%
witnesses_missing = x_train[x_train["Witnesses"] == "MISSINGVALUE"].index
x_train, y_train = x_train.drop(witnesses_missing), y_train.drop(witnesses_missing)
x_train["Witnesses"] = x_train["Witnesses"].astype('int')

# %%
totalclaim_missing = x_train[x_train["AmountOfTotalClaim"] == "MISSEDDATA"].index
x_train, y_train = x_train.drop(totalclaim_missing), y_train.drop(totalclaim_missing)
x_train["AmountOfTotalClaim"] = x_train["AmountOfTotalClaim"].astype('int')

# %% [markdown]
# ### 3.4 Dealing with duplicate values

# %% [markdown]
# There are no rows that indicate a duplication error

# %%
x_train.duplicated().value_counts()
# Out:
# False    22878
# dtype: int64

# %% [markdown]
# ### 3.5 Rescaling

# %% [markdown]
# ### 3.6 Dealing with Outliers

# %%
policyprem_outliers = x_train[x_train["PolicyAnnualPremium"] < 0].index
x_train, y_train = x_train.drop(policyprem_outliers), y_train.drop(policyprem_outliers)
x_train["PolicyAnnualPremium"] = x_train["PolicyAnnualPremium"].astype('int')

# %% [markdown]
# ### 3.7 Dealing with Collinearity

# %% [markdown]
# ## 4 Technique 1 - Classification, Decision Tree

# %% [markdown]
# ## 5 Technique 2 - Classification, Logistic Regression

# %%
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22878 entries, 20936 to 10825
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   SeverityOfIncident          22878 non-null  object
#  1   AuthoritiesContacted        22878 non-null  object
#  2   IncidentTime                22878 non-null  int64
#  3   NumberOfVehicles            22878 non-null  int64
#  4   PropertyDamage              22878 non-null  object
#  5   BodilyInjuries              22878 non-null  int64
#  6   Witnesses                   22878 non-null  int64
#  7   AmountOfTotalClaim          22878 non-null  int64
#  8   AmountOfInjuryClaim         22878 non-null  int64
#  9   AmountOfPropertyClaim       22878 non-null  int64
#  10  AmountOfVehicleDamage       22878 non-null  int64
#  11  InsuredAge                  22878 non-null  int64
#  12  InsuredZipCode              22878 non-null  int64
# ...

# %%
counts = [x_train[x].value_counts() for x in x_train.columns]

# %%
counts[20]
# Out:
# 250/500     6534
# 100/300     6413
# 500/1000    5560
# 250/300      794
# 100/500      785
# 250/1000     749
# 500/500      698
# 500/300      686
# 100/1000     659
# Name: Policy_CombinedSingleLimit, dtype: int64

# %%
def convert_policycomb(x):
    spl = x.split("/")
    return int(spl[0]) / int(spl[1])
    
convert_policycomb("100/500")
# Out:
# 0.2

# %%
x_train["Policy_CombinedSingleLimit"] = x_train["Policy_CombinedSingleLimit"].apply(convert_policycomb)

# %%
x_train["Policy_CombinedSingleLimit"]
# Out:
# 20936    0.333333
# 19307    0.333333
# 2609     0.500000
# 15420    0.500000
# 21007    0.333333
#            ...
# 27962    0.500000
# 10263    0.333333
# 11822    0.333333
# 8667     0.200000
# 10825    0.333333
# Name: Policy_CombinedSingleLimit, Length: 22878, dtype: float64

# %%
x_train["Policy_CombinedSingleLimit"].hist()
# Out:
# <Axes: >
